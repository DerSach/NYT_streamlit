# %%
import pandas as pd
import plotly.graph_objects as go

# %%
articles_df = pd.read_csv('data/articles_vf6.csv')

# %%
articles_df.head()
# Out:
#    Unnamed: 0                                           uniqueID section  \
# 0           0  nyt://article/00036db7-8494-5141-b0ac-414118ca...    U.S.
# 1           1  nyt://article/00074f13-bb5f-57c0-80e2-df0921cc...  Sports
# 2           2  nyt://article/00170d27-c2ca-5d3a-8c05-f27721c3...    U.S.
# 3           3  nyt://article/001c8c67-95ae-5f45-ad75-3df0948d...    U.S.
# 4           4  nyt://article/00275cc0-a134-5bfc-8b8c-4a10273e...    Arts
#
#                                             headline  month  year  day  \
# 0  Michael Flynn Moves to Withdraw Guilty Plea in...      1  2020   15
# 1  The Champions League Returns With a Plan for E...      8  2020   10
# 2  Democrats Fear Partisan Slant at Postal Servic...      9  2020    9
# 3  Early Voting Numbers in Georgia Senate Races P...     12  2020   30
# 4  Nick Cave’s Truth May Be Writ Large, but Is It...     11  2020   11
#
#                                            unique_kw  \
# ...

# %%
month_dico = {1: 'Jan',
             2: 'Feb',
             3: 'Mar',
             4: 'Apr',
             5: 'May',
             6: 'Jun',
             7: 'Jul',
             8: 'Aug',
             9: 'Sep',
             10: 'Oct',
             11: 'Nov',
             12: 'Dec'}

# %%
def plot_evolution_score(df, keyword1, keyword2):
    df1 = df[df['unique_kw'].str.contains(keyword1)]
    grouped_df = df1.groupby('month', as_index = False).agg({'debate_score':'mean'})
#    grouped_df = grouped_df.sort_values(by = 'month', inplace = True)
#    print(grouped_df)
    grouped_df['month'] = grouped_df['month'].map(month_dico)
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=grouped_df['month'], y=grouped_df['debate_score']*1000,
                    name=keyword1))
    df2 = df[df['unique_kw'].str.contains(keyword2)]
    grouped_df = df2.groupby('month', as_index = False).agg({'debate_score':'mean'})
    grouped_df['month'] = grouped_df['month'].map(month_dico)
    fig.add_trace(go.Scatter(x=grouped_df['month'], y=grouped_df['debate_score']*1000,
                name=keyword2))
    return fig

# %%
plot_evolution_score(articles_df, '', 'anxiety')
# Out:
# <div>                            <div id="e0d96760-058f-40b9-83ee-65261f246203" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0d96760-058f-40b9-83ee-65261f246203")) {                    Plotly.newPlot(                        "e0d96760-058f-40b9-83ee-65261f246203",                        [{"name": "mexico", "type": "scatter", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"], "y": [31.287848077944783, 69.18487751343775, 10.93760963011762, 27.944926098529294, 16.32267457239565, 39.642630628617646, 39.324026533257936, 19.2123272517107, 46.98646371112495, 19.512505670148812, 5.504051800995, 22.139823304204942]}, {"name": "anxiety", "type": "scatter", "x": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug",
# ...

# %%
articles_df['unique_kw'].value_counts()
# Out:
# []                                                                                                                                                                                          724
# ['crossword', 'puzzle']                                                                                                                                                                     223
# ['coronavirus']                                                                                                                                                                             164
# ['crossword', 'puzzle', 'constructor']                                                                                                                                                       57
# ['new', 'york', 'city']                                                                                                                                                                      53
# ...

# %%
lok_df = pd.read_csv('data/list_of_keywords.csv')

# %%
lok_df.head()
# Out:
#    Unnamed: 0      keyword  nb_occ  share_of_article
# 0           0  coronavirus    6470             0.395
# 1           1        state    6116             0.373
# 2           2       united    5307             0.324
# 3           3    2019-ncov    5278             0.322
# 4           4     politics    3642             0.222

# %%
list(lok_df['nb_occ'])[list(lok_df['keyword']).index('state')]
# Out:
# 6116

# %%
len(articles_df[articles_df['unique_kw'].str.contains(str('efef'))])
# Out:
# 0

# %%
df3 = articles_df[(articles_df['unique_kw'].str.contains('climate'))
#                  &(articles_df['month'] == 2)
                   ]

# %%
pd.set_option('display.max_colwidth', None)
df3.sort_values(by = 'debate_score', ascending = False)
# Out:
#        Unnamed: 0                                                uniqueID  \
# 6775         6775      nyt://article/6c880edc-da58-590e-8e65-118a58c1e908
# 1876         1876      nyt://article/1e513bf2-9f9c-5353-8a0e-bd21587f4ae4
# 15612       15612      nyt://article/fb31470e-e1eb-52ce-ad86-b14161d64f9d
# 1322         1322      nyt://article/15874d44-93ad-5cdf-ac9e-2ad5fa604ca8
# 7280         7280      nyt://article/758322c9-e13f-5920-bbe3-5c0793f6635c
# 4098         4098      nyt://article/41ebf25a-d746-57b1-b7be-3a6acf462661
# 1980         1980      nyt://article/1ffff9df-75ab-5c8b-8ed7-1f81754b6587
# 7529         7529      nyt://article/7954de21-f062-58c1-ac10-3d4ba9f93f1b
# 16284       16284  nyt://interactive/ca6969ac-81a9-594d-8ac2-9915fe8cb03a
# 2575         2575      nyt://article/29caa230-78ad-5a9e-8dca-69f04429f70d
# 9542         9542      nyt://article/997b2f06-0542-5cf8-8cb8-cf75c2597901
# 10072       10072      nyt://article/a28d28ce-8f4a-5f9f-938e-61446ceb26f2
# ...

# %%
kw_ds_dict = {}

for kw in lok_df['keyword']:
    print(kw)
    if len(articles_df[articles_df['unique_kw'].str.contains(str(kw))]) != 0:
        kw_df = articles_df[articles_df['unique_kw'].str.contains(str(kw))]
        kw_ds_dict[kw] = kw_df.debate_score.mean()
    else:
        kw_ds_dict[kw] = 0
# Out:
# coronavirus
# state
# united
# 2019-ncov
# politics
# government
# trump
# 2020
# election
# donald
# presidential
# black
# new
# us
# quarantine
# party
# life
# york
# book
# jr
# ny
# inc
# program
# city
# joseph
# biden
# tv
# democratic
# real
# estate
# culture
# national
# people
# housing
# service
# protest
# movie
# republican
# international
# residential
# department
# china
# health
# medium
# manhattan
# economic
# death
# crossword
# george
# job
# institutional
# disease
# police
# university
# movement
# 's
# reopenings
# economy
# relation
# theater
# woman
# defense
# social
# shutdown
# medical
# public
# nyc
# news
# music
# literature
# floyd
# labor
# race
# computer
# calif
# family
# security
# house
# senate
# art
# your-feed-science
# child
# ethnicity
# voter
# epidemic
# television
# voting
# center
# research
# content
# type
# food
# restaurant
# world
# puzzle
# travel
# military
# girl
# play
# education
# act
# federal
# fatality
# discrimination
# ...

# %%
kw_ds_dict
# Out:
# {'coronavirus': 0.02867274385609474,
#  'state': 0.02300015327505037,
#  'united': 0.02101977098756572,
#  '2019-ncov': 0,
#  'politics': 0.018567091334690592,
#  'government': 0.0186781312368414,
#  'trump': 0.017982081396886406,
#  '2020': 0,
#  'election': 0.013825138384022616,
#  'donald': 0.01786460734437279,
#  'presidential': 0.013958123284726296,
#  'black': 0.026337190770250353,
#  'new': 0.024843169131980487,
#  'us': 0.02786305207628345,
#  'quarantine': 0.036057505040854546,
#  'party': 0.014031957579476626,
#  'life': 0.039050530490852886,
#  'york': 0.02230028797098156,
#  'book': 0.03835604724644089,
#  'jr': 0.014455541444237434,
#  'ny': 0.02500509596557682,
#  'inc': 0.03570186763217282,
#  'program': 0.0193704402847869,
#  'city': 0.026282140838958086,
#  'joseph': 0.014654759741451119,
#  'biden': 0.013992950644756572,
#  'tv': 0.017470563487802838,
#  'democratic': 0.012807894508653012,
#  'real': 0.033234538661269505,
#  'estate': 0.027955457003222463,
# ...

# %%
dict_occ = {}

for kw in kw_ds_dict.keys():
    dict_occ[kw] = list(lok_df['nb_occ'])[list(lok_df['keyword']).index(kw)]

# %%
import numpy as np

d = {'keyword': list(kw_ds_dict.keys()), 'debate_score': list(kw_ds_dict.values()), 'nb_occ': list(dict_occ.values())}

sumup_df = pd.DataFrame(data = d)

# %%
sumup_df.sort_values(by = 'debate_score', ascending = False).head(50)
# Out:
#              keyword  debate_score  nb_occ
# 1260         reality      0.195420      28
# 1085        alliance      0.156825      36
# 982    massachusetts      0.148100      41
# 1003      innovation      0.144007      40
# 697     relationship      0.134713      61
# 5384             fan      0.134696       3
# 781           infant      0.134696      54
# 836       artificial      0.131076      51
# 651           dating      0.129459      66
# 672              boy      0.118006      65
# 8786             aby      0.105031       2
# 614             baby      0.105031      71
# 1290           oscar      0.100587      27
# 1132        southern      0.099152      34
# 310         emission      0.093317     147
# 339       greenhouse      0.091103     133
# 482            metoo      0.090272      91
# 320       technology      0.086975     140
# 8153            tech      0.086975       2
# 129        parenting      0.085313     340
# 1024         lincoln      0.085304      39
# ...

# %%
import plotly.express as px
fig = px.scatter(sumup_df, x='debate_score', y='nb_occ', hover_name = 'keyword')
fig.show()
# Out:
# <div>                            <div id="bec279ce-eeeb-4e20-bd8d-d50d4e176dd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bec279ce-eeeb-4e20-bd8d-d50d4e176dd8")) {                    Plotly.newPlot(                        "bec279ce-eeeb-4e20-bd8d-d50d4e176dd8",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>debate_score=%{x}<br>nb_occ=%{y}<extra></extra>", "hovertext": ["coronavirus", "state", "united", "2019-ncov", "politics", "government", "trump", "2020", "election", "donald", "presidential", "black", "new", "us", "quarantine", "party", "life", "york", "book", "jr", "ny", "inc", "program", "city", "joseph", "biden", "tv", "democratic", "real", "estate", "culture", "national", "people", "housing", "service", "protest",
# ...
