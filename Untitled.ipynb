# %%
import pandas as pd

# %%
kw_df = pd.read_csv('/Users/sachalehmann/code/DerSach/NYT_streamlit/data/list_of_keywords.csv')

# %%
kw_df.head(50)
# Out:
#     Unnamed: 0        keyword  nb_occ  share_of_article
# 0            0    coronavirus    6470             0.395
# 1            1          state    6116             0.373
# 2            2         united    5307             0.324
# 3            3      2019-ncov    5278             0.322
# 4            4       politics    3642             0.222
# 5            5     government    3609             0.220
# 6            6          trump    3127             0.191
# 7            7           2020    3093             0.189
# 8            8       election    2870             0.175
# 9            9         donald    2859             0.175
# 10          10   presidential    2328             0.142
# 11          11          black    2058             0.126
# 12          12            new    2010             0.123
# 13          13             us    1972             0.120
# 14          14     quarantine    1927             0.118
# 15          15          party    1873             0.114
# ...

# %%
kw_df['nb_occ'].max()
# Out:
# 6470
